# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/sales_data.csv")

df.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11-11-2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675  02-05-2014  02-07-2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948  11-05-2014  11-06-2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#       2 df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=False)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=False)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=False)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=False)

# %%
import pandas as pd

df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=False)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=False)

# %%
import pandas as pd

df = pd.read_csv("data/sales_data.csv")

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=False)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed', dayfirst=False)

# %%
df.info()

# %%
df.isna().sum()

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df[['Order Date', 'Ship Date', 'Shipping Days']].head()

# %%
df['Shipping Days'].describe()

# %%
df.groupby('Order Priority')['Shipping Days'].mean().sort_values()

# %%
df.groupby('Order Priority')['Shipping Days'].describe()

# %%
df[df['Shipping Days'] > 4].shape

# %%
df[df['Shipping Days'] > 4]['Order Priority'].value_counts()

# %%
import pandas as pd
df = pd.read_csv("data/sales_data.csv")

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed')

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df[df['Shipping Days'] > 4]['Order Priority'].value_counts()

# %%
df.groupby(df['Shipping Days'] > 4)['Profit'].mean()

# %%
df.groupby(df['Shipping Days'] > 4)['Sales'].mean()

# %%
df.groupby(df['Shipping Days'] > 4)['Quantity'].mean()

# %%
df.groupby(df['Shipping Days'] > 4)['Quantity'].mean()

# %%
df.groupby(df['Shipping Days'] > 4)['Quantity'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shipping Days'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.groupby(df['Shipping Days'] > 4)['Quantity'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Shipping Days'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#       2 df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed')

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df[['Order Date','Ship Date','Shipping Days']].head()
# Out:
#   Order Date  Ship Date  Shipping Days
# 0 2014-11-11 2014-11-13              2
# 1 2014-02-05 2014-02-07              2
# 2 2014-10-17 2014-10-18              1
# 3 2014-01-28 2014-01-30              2
# 4 2014-11-05 2014-11-06              1

# %%
df[df['Shipping Days'] > 4].shape
# Out:
# (209, 25)

# %%
df.groupby(df['Shipping Days'] > 4)['Profit'].mean()
# Out:
# Shipping Days
# False    260.963793
# True     394.727656
# Name: Profit, dtype: float64

# %%
df.groupby(df['Shipping Days'] > 4)['Quantity'].mean()
# Out:
# Shipping Days
# False    5.530973
# True     5.660287
# Name: Quantity, dtype: float64

# %%
df.groupby(df['Shipping Days'] > 4)['Sales'].mean()
# Out:
# Shipping Days
# False    1647.460759
# True     1951.339761
# Name: Sales, dtype: float64

# %%
df.groupby('Order Priority')['Shipping Days'].mean()
# Out:
# Order Priority
# Critical    1.744275
# High        2.720430
# Low         6.390244
# Medium      3.975385
# Name: Shipping Days, dtype: float64

# %%
df.to_csv("clean_order_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv("clean_order_data.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("data/sales_data.csv")

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='mixed')

# %%
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.to_csv("clean_order_data.csv", index=False)
